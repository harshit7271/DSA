# %%
names = ['Harshit', 'Ramesh', 'Suresh', 'Amam', 'Aditya']

# %%
for i in range(len(names)):
    print(i, names[i])
# Out:
# 0 Harshit
# 1 Ramesh
# 2 Suresh
# 3 Amam
# 4 Aditya

# %%
# rather we will use enumerate
for j in enumerate(names):
    print(j)
# Out:
# (0, 'Harshit')
# (1, 'Ramesh')
# (2, 'Suresh')
# (3, 'Amam')
# (4, 'Aditya')

# %%
for j, name in enumerate(names, start=1):
    print(j, name)
# Out:
# 1 Harshit
# 2 Ramesh
# 3 Suresh
# 4 Amam
# 5 Aditya
